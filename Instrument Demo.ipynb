# %%
from poandy.controller.instrument import InstrumentController
from poandy.controller.account import AccountController

# %%
account_id = AccountController.get_default_account_id()

# %%
AccountController.get_tradeable_instruments(account_id, names_only=True)
# Out:
# ['XAU_AUD',
#  'AUD_CHF',
#  'USD_INR',
#  'UK10YB_GBP',
#  'DE10YB_EUR',
#  'USD_SEK',
#  'GBP_SGD',
#  'US30_USD',
#  'SOYBN_USD',
#  'XAG_AUD',
#  'SGD_JPY',
#  'SGD_HKD',
#  'EUR_CHF',
#  'USB30Y_USD',
#  'XAU_NZD',
#  'NZD_CAD',
#  'XAU_GBP',
#  'XAU_JPY',
#  'EUR_NOK',
#  'USD_JPY',
#  'EUR_TRY',
#  'SG30_SGD',
#  'AUD_HKD',
#  'NZD_SGD',
#  'XAG_CHF',
#  'EUR_NZD',
#  'XPT_USD',
#  'NL25_EUR',
#  'XAU_EUR',
#  'EUR_SGD',
#  'XAU_SGD',
#  'TRY_JPY',
#  'USD_CHF',
#  'AUD_SGD',
#  'EUR_CZK',
#  'TWIX_USD',
#  'CORN_USD',
#  'WTICO_USD',
#  'XAU_USD',
#  'EUR_CAD',
#  'AUD_USD',
#  'GBP_PLN',
#  'EUR_USD',
#  'NAS100_USD',
#  'XAU_HKD',
#  'CAD_HKD',
#  'NZD_CHF',
#  'CHF_HKD',
#  'USD_ZAR',
#  'EUR_JPY',
#  'NZD_JPY',
#  'EU50_EUR',
#  'AU200_AUD',
#  'USD_TRY',
#  'GBP_JPY',
#  'EUR_DKK',
#  'EUR_PLN',
#  'EUR_HKD',
#  'FR40_EUR',
#  'GBP_CAD',
#  'USD_SAR',
#  'HK33_HKD',
#  'XAG_USD',
#  'USB05Y_USD',
#  'USD_THB',
#  'GBP_CHF',
#  'UK100_GBP',
#  'USD_CAD',
#  'SGD_CHF',
# ...

# %%
InstrumentController.get_candles("USD_CAD")
# Out:
# {'instrument': 'USD_CAD',
#  'granularity': 'S5',
#  'candles': [{'complete': True,
#    'volume': 2,
#    'time': '2020-08-27T18:30:50.000000000Z',
#    'mid': {'o': '1.31132', 'h': '1.31132', 'l': '1.31130', 'c': '1.31130'}},
#   {'complete': True,
#    'volume': 1,
#    'time': '2020-08-27T18:30:55.000000000Z',
#    'mid': {'o': '1.31132', 'h': '1.31132', 'l': '1.31132', 'c': '1.31132'}},
#   {'complete': True,
#    'volume': 7,
#    'time': '2020-08-27T18:31:00.000000000Z',
#    'mid': {'o': '1.31129', 'h': '1.31137', 'l': '1.31127', 'c': '1.31135'}},
#   {'complete': True,
#    'volume': 1,
#    'time': '2020-08-27T18:31:05.000000000Z',
#    'mid': {'o': '1.31133', 'h': '1.31133', 'l': '1.31133', 'c': '1.31133'}},
#   {'complete': True,
#    'volume': 1,
#    'time': '2020-08-27T18:31:10.000000000Z',
#    'mid': {'o': '1.31130', 'h': '1.31130', 'l': '1.31130', 'c': '1.31130'}},
#   {'complete': True,
#    'volume': 2,
#    'time': '2020-08-27T18:31:15.000000000Z',
# ...

# %%
InstrumentController.get_orderbook("USD_CAD")
# Out:
# {'orderBook': {'instrument': 'USD_CAD',
#   'time': '2020-08-27T19:20:00Z',
#   'unixTime': '1598556000',
#   'price': '1.31285',
#   'bucketWidth': '0.00050',
#   'buckets': [{'price': '0.00000',
#     'longCountPercent': '0.0453',
#     'shortCountPercent': '0.0227'},
#    {'price': '0.00050',
#     'longCountPercent': '0.0091',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.00100',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0045'},
#    {'price': '0.00250',
#     'longCountPercent': '0.0045',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.00500',
#     'longCountPercent': '0.0045',
#     'shortCountPercent': '0.0045'},
#    {'price': '0.01000',
#     'longCountPercent': '0.0045',
#     'shortCountPercent': '0.0136'},
#    {'price': '0.02000',
#     'longCountPercent': '0.0045',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.05000',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0091'},
#    {'price': '0.05200',
# ...

# %%
InstrumentController.get_positionbook("USD_JPY")
# Out:
# {'positionBook': {'instrument': 'USD_JPY',
#   'time': '2020-08-27T19:20:00Z',
#   'unixTime': '1598556000',
#   'price': '106.580',
#   'bucketWidth': '0.050',
#   'buckets': [{'price': '99.600',
#     'longCountPercent': '0.0036',
#     'shortCountPercent': '0.0000'},
#    {'price': '99.850',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0036'},
#    {'price': '99.950',
#     'longCountPercent': '0.0036',
#     'shortCountPercent': '0.0036'},
#    {'price': '100.000',
#     'longCountPercent': '0.0036',
#     'shortCountPercent': '0.0000'},
#    {'price': '100.150',
#     'longCountPercent': '0.0255',
#     'shortCountPercent': '0.0036'},
#    {'price': '100.200',
#     'longCountPercent': '0.0036',
#     'shortCountPercent': '0.0000'},
#    {'price': '100.250',
#     'longCountPercent': '0.0073',
#     'shortCountPercent': '0.0109'},
#    {'price': '100.300',
#     'longCountPercent': '0.0182',
#     'shortCountPercent': '0.0000'},
#    {'price': '100.350',
# ...

# %%
# TODO: Add more examples show how different params can be used
